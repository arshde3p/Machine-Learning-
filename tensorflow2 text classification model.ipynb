# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

data = keras.datasets.imdb

(train_data, train_labels),(test_data,test_labels) = data.load_data(num_words = 10000)
print(train_data[0])

word_index = data.get_word_index()
# this gives us the tuple where the key and value of every word is stored 

word_index = {k:(v+3) for k,v in word_index.items()}
# we started at v+3 b/c the first three keys describe a special character for our word mappings

word_index["<PAD>"] = 0
word_index["<START>"] = 1 # <START> adds to the beginning of the text 
word_index["<UNK>"] = 2 #UNK = <UNKNOWN> is added where the definition is missing 
word_index["<UNUSED>"] = 3
# since all the keys and values in the dictionary start from 0 here we are assigning our own values so that we can start the numbering from v+3
# so that if we get values that are not defined we can assign them to these values 

# what PAD - padding does is that it makes the length of all movie reviews to be of the same length
# by adding extra 0's at the end of the list

reverse_word_index = dict([(value,key) for (key,value) in word_index.items()])
# this actually swaps all the values and the keys and puts it in another dictionary
# intially the strings are pointing to the numbers and what we want is the numbers to point to the string

# in this we are preprocessing the data so that our model can accept the data
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value = word_index["<PAD>"], padding ="post", maxlen = 250 )
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value = word_index["<PAD>"], padding ="post", maxlen = 250 )

# print(len(train_data),len(test_data))

def decode_review(text):
    return " ".join([reverse_word_index.get(i,"?") for i in text])

# print(len(test_data[0]),len(test_data[1]))
# print(decode_review(test_data[0]))

# ========model down here=========

# model can be defined in two ways
#1
# model = keras.Sequential([
#     keras.layers.Embedding(10000,16),
#     keras.layers.GlobalAveragePooling1D(),
#     keras.layers.Dense(16,activation = "relu"),
#     keras.layers.Dense(1,activation = "sigmoid")
# ])
#2
model = keras.Sequential()
model.add(keras.layers.Embedding(10000,16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16,activation = "relu"))
model.add(keras.layers.Dense(1,activation = "sigmoid"))

model.summary()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"] )

X_val = train_data[:10000]
X_train = train_data[10000:]

y_val = train_labels[:10000]
y_train = train_labels[10000:]

fitModel = model.fit(X_train, y_train, epochs = 40 , batch_size = 512, validation_data=(X_val, y_val),verbose=1)

results = model.evaluate(test_data, test_labels)
print(results)
model.save("Text_Classification_Model.h5")
# test_review = test_data[0]
# predict = model.predict([test_review])
# print("Review: ")
# print(decode_review(test_review))
# print("Prediction: "+ str(predict[0]))
# print("Actual: "+ str(test_labels[0]))
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_5 ( (None, 16)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 2s 100us/sample - loss: 0.6916 - accuracy: 0.5709 - val_loss: 0.6888 - val_accuracy: 0.5890
# Epoch 2/40
# 15000/15000 [==============================] - 1s 59us/sample - loss: 0.6838 - accuracy: 0.7169 - val_loss: 0.6776 - val_accuracy: 0.7282
# Epoch 3/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.6664 - accuracy: 0.7576 - val_loss: 0.6564 - val_accuracy: 0.7584
# Epoch 4/40
# 15000/15000 [==============================] - 1s 82us/sample - loss: 0.6372 - accuracy: 0.7766 - val_loss: 0.6245 - val_accuracy: 0.7761
# Epoch 5/40
# 15000/15000 [==============================] - 1s 67us/sample - loss: 0.5966 - accuracy: 0.7971 - val_loss: 0.5825 - val_accuracy: 0.7917
# Epoch 6/40
# 15000/15000 [==============================] - 1s 72us/sample - loss: 0.5474 - accuracy: 0.8195 - val_loss: 0.5361 - val_accuracy: 0.8059
# Epoch 7/40
# 15000/15000 [==============================] - 1s 83us/sample - loss: 0.4958 - accuracy: 0.8386 - val_loss: 0.4910 - val_accuracy: 0.8284
# Epoch 8/40
# 15000/15000 [==============================] - 1s 68us/sample - loss: 0.4470 - accuracy: 0.8539 - val_loss: 0.4490 - val_accuracy: 0.8392
# Epoch 9/40
# 15000/15000 [==============================] - 1s 66us/sample - loss: 0.4037 - accuracy: 0.8689 - val_loss: 0.4145 - val_accuracy: 0.8487
# Epoch 10/40
# 15000/15000 [==============================] - 1s 66us/sample - loss: 0.3676 - accuracy: 0.8795 - val_loss: 0.3870 - val_accuracy: 0.8570
# Epoch 11/40
# 15000/15000 [==============================] - 1s 69us/sample - loss: 0.3378 - accuracy: 0.8876 - val_loss: 0.3657 - val_accuracy: 0.8618
# Epoch 12/40
# 15000/15000 [==============================] - 1s 68us/sample - loss: 0.3129 - accuracy: 0.8945 - val_loss: 0.3494 - val_accuracy: 0.8682
# Epoch 13/40
# 15000/15000 [==============================] - 1s 70us/sample - loss: 0.2914 - accuracy: 0.9009 - val_loss: 0.3351 - val_accuracy: 0.8729
# Epoch 14/40
# 15000/15000 [==============================] - 1s 71us/sample - loss: 0.2734 - accuracy: 0.9059 - val_loss: 0.3248 - val_accuracy: 0.8718
# Epoch 15/40
# 15000/15000 [==============================] - 1s 69us/sample - loss: 0.2572 - accuracy: 0.9107 - val_loss: 0.3153 - val_accuracy: 0.8762
# Epoch 16/40
# 15000/15000 [==============================] - 1s 67us/sample - loss: 0.2433 - accuracy: 0.9155 - val_loss: 0.3082 - val_accuracy: 0.8793
# Epoch 17/40
# 15000/15000 [==============================] - 1s 68us/sample - loss: 0.2296 - accuracy: 0.9210 - val_loss: 0.3023 - val_accuracy: 0.8814
# Epoch 18/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.2178 - accuracy: 0.9244 - val_loss: 0.2973 - val_accuracy: 0.8814
# Epoch 19/40
# 15000/15000 [==============================] - 1s 64us/sample - loss: 0.2075 - accuracy: 0.9288 - val_loss: 0.2957 - val_accuracy: 0.8783
# Epoch 20/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1971 - accuracy: 0.9333 - val_loss: 0.2906 - val_accuracy: 0.8839
# Epoch 21/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1876 - accuracy: 0.9378 - val_loss: 0.2885 - val_accuracy: 0.8847
# Epoch 22/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1790 - accuracy: 0.9421 - val_loss: 0.2870 - val_accuracy: 0.8849
# Epoch 23/40
# 15000/15000 [==============================] - 1s 65us/sample - loss: 0.1707 - accuracy: 0.9447 - val_loss: 0.2858 - val_accuracy: 0.8854
# Epoch 24/40
# 15000/15000 [==============================] - 1s 69us/sample - loss: 0.1630 - accuracy: 0.9485 - val_loss: 0.2852 - val_accuracy: 0.8860
# Epoch 25/40
# 15000/15000 [==============================] - 1s 70us/sample - loss: 0.1558 - accuracy: 0.9516 - val_loss: 0.2852 - val_accuracy: 0.8863
# Epoch 26/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1490 - accuracy: 0.9535 - val_loss: 0.2856 - val_accuracy: 0.8866
# Epoch 27/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.1429 - accuracy: 0.9565 - val_loss: 0.2871 - val_accuracy: 0.8852
# Epoch 28/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1366 - accuracy: 0.9588 - val_loss: 0.2896 - val_accuracy: 0.8836
# Epoch 29/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1321 - accuracy: 0.9603 - val_loss: 0.2890 - val_accuracy: 0.8868
# Epoch 30/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1257 - accuracy: 0.9636 - val_loss: 0.2909 - val_accuracy: 0.8867
# Epoch 31/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.1204 - accuracy: 0.9654 - val_loss: 0.2927 - val_accuracy: 0.8848
# Epoch 32/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.1157 - accuracy: 0.9676 - val_loss: 0.2966 - val_accuracy: 0.8840
# Epoch 33/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.1107 - accuracy: 0.9680 - val_loss: 0.2972 - val_accuracy: 0.8858
# Epoch 34/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.1061 - accuracy: 0.9718 - val_loss: 0.3014 - val_accuracy: 0.8833
# Epoch 35/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.1024 - accuracy: 0.9728 - val_loss: 0.3041 - val_accuracy: 0.8830
# Epoch 36/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.0981 - accuracy: 0.9731 - val_loss: 0.3064 - val_accuracy: 0.8832
# Epoch 37/40
# 15000/15000 [==============================] - 1s 63us/sample - loss: 0.0944 - accuracy: 0.9749 - val_loss: 0.3101 - val_accuracy: 0.8826
# Epoch 38/40
# 15000/15000 [==============================] - 1s 62us/sample - loss: 0.0902 - accuracy: 0.9775 - val_loss: 0.3130 - val_accuracy: 0.8827
# Epoch 39/40
# 15000/15000 [==============================] - 1s 71us/sample - loss: 0.0867 - accuracy: 0.9783 - val_loss: 0.3220 - val_accuracy: 0.8798
# Epoch 40/40
# 15000/15000 [==============================] - 1s 87us/sample - loss: 0.0837 - accuracy: 0.9792 - val_loss: 0.3209 - val_accuracy: 0.8810
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.34356183853149413, 0.87008]
